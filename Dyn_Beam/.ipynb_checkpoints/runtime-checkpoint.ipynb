# %%
# %run pred_LSTM_experiment.py
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Train for 200 steps, validate for 20 steps
# Epoch 1/50
# 198/200 [============================>.] - ETA: 0s - loss: 0.5422 - coeff_determination: 0.4735
# Epoch 00001: val_loss improved from inf to 0.39121, saving model to checkpoint.keras
# 200/200 [==============================] - 4s 21ms/step - loss: 0.5408 - coeff_determination: 0.4760 - val_loss: 0.3912 - val_coeff_determination: 0.7096
# Epoch 2/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3661 - coeff_determination: 0.7712
# Epoch 00002: val_loss improved from 0.39121 to 0.34346, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3656 - coeff_determination: 0.7718 - val_loss: 0.3435 - val_coeff_determination: 0.7684
# Epoch 3/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3342 - coeff_determination: 0.8011
# Epoch 00003: val_loss improved from 0.34346 to 0.32981, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3340 - coeff_determination: 0.8015 - val_loss: 0.3298 - val_coeff_determination: 0.7829
# Epoch 4/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3274 - coeff_determination: 0.8185
# Epoch 00004: val_loss improved from 0.32981 to 0.32147, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3273 - coeff_determination: 0.8184 - val_loss: 0.3215 - val_coeff_determination: 0.7923
# Epoch 5/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3173 - coeff_determination: 0.8077
# Epoch 00005: val_loss improved from 0.32147 to 0.31773, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3172 - coeff_determination: 0.8081 - val_loss: 0.3177 - val_coeff_determination: 0.7949
# Epoch 6/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3146 - coeff_determination: 0.8190
# Epoch 00006: val_loss improved from 0.31773 to 0.31706, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3148 - coeff_determination: 0.8196 - val_loss: 0.3171 - val_coeff_determination: 0.7974
# Epoch 7/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3128 - coeff_determination: 0.8253
# Epoch 00007: val_loss improved from 0.31706 to 0.31336, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3129 - coeff_determination: 0.8250 - val_loss: 0.3134 - val_coeff_determination: 0.7986
# Epoch 8/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3099 - coeff_determination: 0.8279
# Epoch 00008: val_loss improved from 0.31336 to 0.31316, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3099 - coeff_determination: 0.8277 - val_loss: 0.3132 - val_coeff_determination: 0.7996
# Epoch 9/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3065 - coeff_determination: 0.8292
# Epoch 00009: val_loss improved from 0.31316 to 0.30979, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3067 - coeff_determination: 0.8290 - val_loss: 0.3098 - val_coeff_determination: 0.8032
# Epoch 10/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3065 - coeff_determination: 0.8296
# Epoch 00010: val_loss improved from 0.30979 to 0.30761, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3065 - coeff_determination: 0.8289 - val_loss: 0.3076 - val_coeff_determination: 0.8030
# Epoch 11/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3048 - coeff_determination: 0.8227
# Epoch 00011: val_loss did not improve from 0.30761
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3047 - coeff_determination: 0.8230 - val_loss: 0.3077 - val_coeff_determination: 0.8038
# Epoch 12/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3044 - coeff_determination: 0.8335
# Epoch 00012: val_loss improved from 0.30761 to 0.30694, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3046 - coeff_determination: 0.8338 - val_loss: 0.3069 - val_coeff_determination: 0.8044
# Epoch 13/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3058 - coeff_determination: 0.8288
# Epoch 00013: val_loss improved from 0.30694 to 0.30543, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3055 - coeff_determination: 0.8296 - val_loss: 0.3054 - val_coeff_determination: 0.8042
# Epoch 14/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3016 - coeff_determination: 0.8322
# Epoch 00014: val_loss improved from 0.30543 to 0.30455, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3016 - coeff_determination: 0.8319 - val_loss: 0.3046 - val_coeff_determination: 0.8073
# Epoch 15/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3017 - coeff_determination: 0.8382
# Epoch 00015: val_loss improved from 0.30455 to 0.30319, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3014 - coeff_determination: 0.8386 - val_loss: 0.3032 - val_coeff_determination: 0.8077
# Epoch 16/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3011 - coeff_determination: 0.8273
# Epoch 00016: val_loss did not improve from 0.30319
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3010 - coeff_determination: 0.8271 - val_loss: 0.3068 - val_coeff_determination: 0.8023
# Epoch 17/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2994 - coeff_determination: 0.8303
# Epoch 00017: val_loss did not improve from 0.30319
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2998 - coeff_determination: 0.8298 - val_loss: 0.3040 - val_coeff_determination: 0.8063
# Epoch 18/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3021 - coeff_determination: 0.8380
# Epoch 00018: val_loss improved from 0.30319 to 0.30229, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3020 - coeff_determination: 0.8381 - val_loss: 0.3023 - val_coeff_determination: 0.8074
# Epoch 19/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3008 - coeff_determination: 0.8357
# Epoch 00019: val_loss improved from 0.30229 to 0.30065, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3006 - coeff_determination: 0.8358 - val_loss: 0.3006 - val_coeff_determination: 0.8070
# Epoch 20/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2970 - coeff_determination: 0.8373
# Epoch 00020: val_loss improved from 0.30065 to 0.30064, saving model to checkpoint.keras
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2971 - coeff_determination: 0.8367 - val_loss: 0.3006 - val_coeff_determination: 0.8069
# Epoch 21/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.3016 - coeff_determination: 0.8385
# Epoch 00021: val_loss did not improve from 0.30064
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3015 - coeff_determination: 0.8381 - val_loss: 0.3029 - val_coeff_determination: 0.8098
# Epoch 22/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2957 - coeff_determination: 0.8297
# Epoch 00022: val_loss did not improve from 0.30064
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2961 - coeff_determination: 0.8297 - val_loss: 0.3015 - val_coeff_determination: 0.8114
# Epoch 23/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2989 - coeff_determination: 0.8343
# Epoch 00023: val_loss improved from 0.30064 to 0.30021, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2993 - coeff_determination: 0.8346 - val_loss: 0.3002 - val_coeff_determination: 0.8101
# Epoch 24/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2995 - coeff_determination: 0.8358
# Epoch 00024: val_loss did not improve from 0.30021
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2993 - coeff_determination: 0.8361 - val_loss: 0.3013 - val_coeff_determination: 0.8101
# Epoch 25/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2990 - coeff_determination: 0.8371
# Epoch 00025: val_loss improved from 0.30021 to 0.30008, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2988 - coeff_determination: 0.8370 - val_loss: 0.3001 - val_coeff_determination: 0.8080
# Epoch 26/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2972 - coeff_determination: 0.8381
# Epoch 00026: val_loss did not improve from 0.30008
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2973 - coeff_determination: 0.8385 - val_loss: 0.3001 - val_coeff_determination: 0.8104
# Epoch 27/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2977 - coeff_determination: 0.8365
# Epoch 00027: val_loss did not improve from 0.30008
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2977 - coeff_determination: 0.8363 - val_loss: 0.3001 - val_coeff_determination: 0.8077
# Epoch 28/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2975 - coeff_determination: 0.8303
# Epoch 00028: val_loss improved from 0.30008 to 0.29939, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2976 - coeff_determination: 0.8302 - val_loss: 0.2994 - val_coeff_determination: 0.8084
# Epoch 29/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2993 - coeff_determination: 0.8403
# Epoch 00029: val_loss did not improve from 0.29939
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2994 - coeff_determination: 0.8403 - val_loss: 0.2999 - val_coeff_determination: 0.8073
# Epoch 30/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2989 - coeff_determination: 0.8365
# Epoch 00030: val_loss did not improve from 0.29939
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2991 - coeff_determination: 0.8364 - val_loss: 0.3012 - val_coeff_determination: 0.8123
# Epoch 31/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2953 - coeff_determination: 0.8378
# Epoch 00031: val_loss did not improve from 0.29939
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2953 - coeff_determination: 0.8372 - val_loss: 0.3000 - val_coeff_determination: 0.8050
# Epoch 32/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2986 - coeff_determination: 0.8427
# Epoch 00032: val_loss improved from 0.29939 to 0.29929, saving model to checkpoint.keras
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2985 - coeff_determination: 0.8426 - val_loss: 0.2993 - val_coeff_determination: 0.8130
# Epoch 33/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2965 - coeff_determination: 0.8282
# Epoch 00033: val_loss improved from 0.29929 to 0.29874, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2965 - coeff_determination: 0.8283 - val_loss: 0.2987 - val_coeff_determination: 0.8095
# Epoch 34/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2968 - coeff_determination: 0.8352
# Epoch 00034: val_loss did not improve from 0.29874
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2970 - coeff_determination: 0.8355 - val_loss: 0.2993 - val_coeff_determination: 0.8093
# Epoch 35/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2981 - coeff_determination: 0.8389
# Epoch 00035: val_loss improved from 0.29874 to 0.29835, saving model to checkpoint.keras
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2980 - coeff_determination: 0.8389 - val_loss: 0.2983 - val_coeff_determination: 0.8125
# Epoch 36/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2989 - coeff_determination: 0.8391
# Epoch 00036: val_loss did not improve from 0.29835
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2987 - coeff_determination: 0.8389 - val_loss: 0.2988 - val_coeff_determination: 0.8119
# Epoch 37/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2949 - coeff_determination: 0.8388
# Epoch 00037: val_loss did not improve from 0.29835
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2951 - coeff_determination: 0.8389 - val_loss: 0.2995 - val_coeff_determination: 0.8095
# Epoch 38/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2981 - coeff_determination: 0.8411
# Epoch 00038: val_loss did not improve from 0.29835
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2978 - coeff_determination: 0.8410 - val_loss: 0.2991 - val_coeff_determination: 0.8115
# Epoch 39/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2968 - coeff_determination: 0.8288
# Epoch 00039: val_loss did not improve from 0.29835
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2968 - coeff_determination: 0.8287 - val_loss: 0.2989 - val_coeff_determination: 0.8133
# Epoch 40/50
# 196/200 [============================>.] - ETA: 0s - loss: 0.2976 - coeff_determination: 0.8367
# Epoch 00040: val_loss did not improve from 0.29835
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.001.
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2975 - coeff_determination: 0.8369 - val_loss: 0.3007 - val_coeff_determination: 0.8117
# Epoch 00040: early stopping

# %%
y_pred = model.predict(x_train_uni)

# %%
y_real = y_train_uni

# %%
plt.plot(y_pred[200:300], label='pred')
plt.plot(y_real[200:300], label='real')
plt.legend()

# %%
(dataset[200, 5]-mean[5])/std[5]
# Out:
# 6.889023006951513

# %%
y_train_uni.shape
# Out:
# (287950,)

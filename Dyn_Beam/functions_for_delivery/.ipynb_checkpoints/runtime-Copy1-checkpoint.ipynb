# %%
from matplotlib import animation
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.loadtxt('./simulations/sine_simul1.txt')

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, 1), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0,1,10)
    y = np.zeros(10)
    y[1:10] = data[i, 0:9] 
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=500, blit=True)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html

writer = animation.PillowWriter
writer.setup(writer,fig, 'movie')

# %%
from IPython.display import display, clear_output

fig, ax = plt.subplots()
l, = ax.plot([0,1.5],[-3,3])

x = np.linspace(0,1,10)
y = np.zeros((360001,10))
y[:, 1:10] = data[:, 0:9] 

animate = lambda i: l.set_data(x, y[i, :]*1e3)

for i in range(2000,2020):
    animate(i)
    clear_output(wait=True)
    display(fig)
    print(i)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-a00bcc56801e> in <module>
#      13     animate(i)
#      14     clear_output(wait=True)
# ---> 15     display(fig)
#      16     print(i)
#      17
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1205                                                                 renderer)
#    1206
#    1207         for tick in ticks_to_draw:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     419
#     420         # now rotate the positions around the first x,y position
# --> 421         xys = M.transform(offset_layout) - (offsetx, offsety)
#     422
#     423         ret = bbox, list(zip(lines, zip(ws, hs), *xys.T)), descent
#
# KeyboardInterrupt:

# %%
# %run experiment_LSTM.py
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 64)                16896
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Train for 300 steps, validate for 50 steps
# Epoch 1/30
# 296/300 [============================>.] - ETA: 0s - loss: 0.0800 - coeff_determination: 0.9206
# Epoch 00001: val_loss improved from inf to 0.00083, saving model to checkpoint.keras
# 300/300 [==============================] - 7s 23ms/step - loss: 0.0789 - coeff_determination: 0.9216 - val_loss: 8.3259e-04 - val_coeff_determination: 0.9991
# Epoch 2/30
# 297/300 [============================>.] - ETA: 0s - loss: 5.0052e-04 - coeff_determination: 0.9995
# Epoch 00002: val_loss improved from 0.00083 to 0.00029, saving model to checkpoint.keras
# 300/300 [==============================] - 4s 14ms/step - loss: 4.9953e-04 - coeff_determination: 0.9995 - val_loss: 2.9066e-04 - val_coeff_determination: 0.9997
# Epoch 3/30
# 297/300 [============================>.] - ETA: 0s - loss: 2.9129e-04 - coeff_determination: 0.9997
# Epoch 00003: val_loss improved from 0.00029 to 0.00018, saving model to checkpoint.keras
# 300/300 [==============================] - 4s 14ms/step - loss: 2.9002e-04 - coeff_determination: 0.9997 - val_loss: 1.8272e-04 - val_coeff_determination: 0.9998
# Epoch 4/30
# 298/300 [============================>.] - ETA: 0s - loss: 2.3387e-04 - coeff_determination: 0.9998
# Epoch 00004: val_loss improved from 0.00018 to 0.00015, saving model to checkpoint.keras
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 5s 15ms/step - loss: 2.3334e-04 - coeff_determination: 0.9998 - val_loss: 1.5109e-04 - val_coeff_determination: 0.9998
# Epoch 5/30
# 297/300 [============================>.] - ETA: 0s - loss: 1.7712e-04 - coeff_determination: 0.9998
# Epoch 00005: val_loss improved from 0.00015 to 0.00014, saving model to checkpoint.keras
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 15ms/step - loss: 1.7667e-04 - coeff_determination: 0.9998 - val_loss: 1.3643e-04 - val_coeff_determination: 0.9999
# Epoch 6/30
# 297/300 [============================>.] - ETA: 0s - loss: 1.4615e-04 - coeff_determination: 0.9999
# Epoch 00006: val_loss improved from 0.00014 to 0.00009, saving model to checkpoint.keras
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4573e-04 - coeff_determination: 0.9999 - val_loss: 9.1075e-05 - val_coeff_determination: 0.9999
# Epoch 7/30
# 297/300 [============================>.] - ETA: 0s - loss: 1.4591e-04 - coeff_determination: 0.9999
# Epoch 00007: val_loss improved from 0.00009 to 0.00006, saving model to checkpoint.keras
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4635e-04 - coeff_determination: 0.9999 - val_loss: 6.3794e-05 - val_coeff_determination: 0.9999
# Epoch 8/30
# 299/300 [============================>.] - ETA: 0s - loss: 1.1629e-04 - coeff_determination: 0.9999
# Epoch 00008: val_loss improved from 0.00006 to 0.00005, saving model to checkpoint.keras
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 5s 15ms/step - loss: 1.1609e-04 - coeff_determination: 0.9999 - val_loss: 5.3509e-05 - val_coeff_determination: 0.9999
# Epoch 9/30
# 297/300 [============================>.] - ETA: 0s - loss: 1.0426e-04 - coeff_determination: 0.9999
# Epoch 00009: val_loss did not improve from 0.00005
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 15ms/step - loss: 1.0401e-04 - coeff_determination: 0.9999 - val_loss: 1.7610e-04 - val_coeff_determination: 0.9998
# Epoch 10/30
# 297/300 [============================>.] - ETA: 0s - loss: 9.8916e-05 - coeff_determination: 0.9999
# Epoch 00010: val_loss did not improve from 0.00005
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 15ms/step - loss: 9.8746e-05 - coeff_determination: 0.9999 - val_loss: 8.6888e-05 - val_coeff_determination: 0.9999
# Epoch 11/30
# 297/300 [============================>.] - ETA: 0s - loss: 1.0933e-04 - coeff_determination: 0.9999
# Epoch 00011: val_loss did not improve from 0.00005
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 15ms/step - loss: 1.0885e-04 - coeff_determination: 0.9999 - val_loss: 6.9489e-05 - val_coeff_determination: 0.9999
# Epoch 12/30
# 296/300 [============================>.] - ETA: 0s - loss: 1.0464e-04 - coeff_determination: 0.9999
# Epoch 00012: val_loss did not improve from 0.00005
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 5s 15ms/step - loss: 1.0795e-04 - coeff_determination: 0.9999 - val_loss: 1.5057e-04 - val_coeff_determination: 0.9998
# Epoch 13/30
# 297/300 [============================>.] - ETA: 0s - loss: 8.2309e-05 - coeff_determination: 0.9999
# Epoch 00013: val_loss did not improve from 0.00005
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
# 300/300 [==============================] - 4s 14ms/step - loss: 8.2124e-05 - coeff_determination: 0.9999 - val_loss: 5.8817e-05 - val_coeff_determination: 0.9999
# Epoch 00013: early stopping

# %%
y_pred = model.predict(x_train_uni)

# %%
# Plot and compare the two signals.
plt.plot(y_train_uni[-1000:], label='true')
plt.plot(y_pred[-1000:], label='pred')
        
# Plot labels etc.
plt.legend()
plt.show()

# %%
from KERAS_utils import prepare_data

# %%
x_train_uni_rnd, y_train_uni_rnd = prepare_data(data, loc_sg,
                                           0, TRAIN_SPLIT,
                                           univariate_past_history,
                                           univariate_future_target)
y_pred_rnd = model.predict(x_train_uni_rnd)
# Plot and compare the two signals.
plt.plot(y_train_uni_rnd[-1000:], label='true')
plt.plot(y_pred_rnd[-1000:], label='pred')
        
# Plot labels etc.
plt.legend()
plt.show()

# %%
data = np.loadtxt('./simulations/simul1.txt')

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f86e63e5ed0>,
#   <matplotlib.lines.Line2D at 0x7f86e5b0f810>,
#   <matplotlib.lines.Line2D at 0x7f86e5ea4c10>,
#   <matplotlib.lines.Line2D at 0x7f86e62985d0>,
#   <matplotlib.lines.Line2D at 0x7f86ac08e090>,
#   <matplotlib.lines.Line2D at 0x7f85f70dbf90>,
#   <matplotlib.lines.Line2D at 0x7f86d02fb250>,
#   <matplotlib.lines.Line2D at 0x7f86d02fb450>,
#   <matplotlib.lines.Line2D at 0x7f86e644d190>,
#   <matplotlib.lines.Line2D at 0x7f86e644d390>,
#   <matplotlib.lines.Line2D at 0x7f86e64405d0>,
#   <matplotlib.lines.Line2D at 0x7f86e643e550>,
#   <matplotlib.lines.Line2D at 0x7f86e644ac50>,
#   <matplotlib.lines.Line2D at 0x7f86e64b65d0>,
#   <matplotlib.lines.Line2D at 0x7f86e65d32d0>,
#   <matplotlib.lines.Line2D at 0x7f86e65a4810>,
#   <matplotlib.lines.Line2D at 0x7f86e644d510>,
#   <matplotlib.lines.Line2D at 0x7f86e653fd50>,
#   <matplotlib.lines.Line2D at 0x7f86e6632710>,
#   <matplotlib.lines.Line2D at 0x7f86e6632ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f86e5b02190>,
#   <matplotlib.lines.Line2D at 0x7f8775daa550>,
#   <matplotlib.lines.Line2D at 0x7f86e5ea4c50>,
#   <matplotlib.lines.Line2D at 0x7f86e62aab90>,
#   <matplotlib.lines.Line2D at 0x7f85f70db450>,
#   <matplotlib.lines.Line2D at 0x7f85f70db950>,
#   <matplotlib.lines.Line2D at 0x7f85f70db9d0>,
#   <matplotlib.lines.Line2D at 0x7f86e5bdf190>,
#   <matplotlib.lines.Line2D at 0x7f86e6444a90>,
#   <matplotlib.lines.Line2D at 0x7f86ac08ecd0>,
#   <matplotlib.lines.Line2D at 0x7f86e643e350>,
#   <matplotlib.lines.Line2D at 0x7f86e6440550>,
#   <matplotlib.lines.Line2D at 0x7f86e64928d0>,
#   <matplotlib.lines.Line2D at 0x7f86e659c750>,
#   <matplotlib.lines.Line2D at 0x7f86e65cef50>,
#   <matplotlib.lines.Line2D at 0x7f86e6544850>,
#   <matplotlib.lines.Line2D at 0x7f86e653f550>,
#   <matplotlib.lines.Line2D at 0x7f86e6544d10>,
#   <matplotlib.lines.Line2D at 0x7f86e653f110>,
#   <matplotlib.lines.Line2D at 0x7f86e6633f10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f86e5b02110>,
#   <matplotlib.lines.Line2D at 0x7f86e6298410>,
#   <matplotlib.lines.Line2D at 0x7f86ac08e750>,
#   <matplotlib.lines.Line2D at 0x7f86d02fb910>,
#   <matplotlib.lines.Line2D at 0x7f86e644d450>,
#   <matplotlib.lines.Line2D at 0x7f86e64400d0>,
#   <matplotlib.lines.Line2D at 0x7f86e643e490>,
#   <matplotlib.lines.Line2D at 0x7f86e644a090>,
#   <matplotlib.lines.Line2D at 0x7f86e5bdf490>,
#   <matplotlib.lines.Line2D at 0x7f86e644dfd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f86e5ea4810>,
#   <matplotlib.lines.Line2D at 0x7f86e62aa310>,
#   <matplotlib.lines.Line2D at 0x7f85f70dba10>,
#   <matplotlib.lines.Line2D at 0x7f86e5bdf7d0>,
#   <matplotlib.lines.Line2D at 0x7f86e62aa290>,
#   <matplotlib.lines.Line2D at 0x7f86e644a7d0>,
#   <matplotlib.lines.Line2D at 0x7f86e654ab10>,
#   <matplotlib.lines.Line2D at 0x7f86e6544d90>,
#   <matplotlib.lines.Line2D at 0x7f86e6637fd0>,
#   <matplotlib.lines.Line2D at 0x7f86e66338d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f86e5b0f910>,
#   <matplotlib.lines.Line2D at 0x7f86e6451a10>,
#   <matplotlib.lines.Line2D at 0x7f85fc85df50>,
#   <matplotlib.lines.Line2D at 0x7f86d02fb090>,
#   <matplotlib.lines.Line2D at 0x7f86e6440d10>,
#   <matplotlib.lines.Line2D at 0x7f86e644abd0>,
#   <matplotlib.lines.Line2D at 0x7f86e659ab50>,
#   <matplotlib.lines.Line2D at 0x7f86e65a4a50>,
#   <matplotlib.lines.Line2D at 0x7f86e6444c50>,
#   <matplotlib.lines.Line2D at 0x7f86e66324d0>],
#  'means': []}
